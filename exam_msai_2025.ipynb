# %% [markdown]
# # Problem 1
#
# 1. Check convexity of the following sets
#
#   - (1 pts) $$ \mathbb{X} = \{ x \in \mathbb{R}^n \mid x_i \geq 0, \; \| x\|_{\infty} \leq 1 \} $$
#   - (1 pts) $$ \mathbb{G} = \{ X \in \mathbb{R}^{n \times n} \mid y^\top X y \leq 0 \}, $$
#   where $y$ is a given fixed vector of the proper dimension
#
# 2. Check convexity/concavity of the following functions, whose domain is $\mathbb{R}^n$ or $\mathbb{S}^n$
#
# - (1 pts) $f(x) = \max \{ c^\top x + b, \|x\|_2 \}$
#
# - (1 pts) $f(x) = \|Ax - b\|_{50} + \exp\left(-\sum_{i=1}^n x_i\right)$
#
# - (2 pts) $f(X) = \lambda_{\min}(X)$ is the smallest eigenvalue of a given symmetric square matrix $X$
#
# 3. Solve analytically the following optimization problems
#
# - (1 pts) $\max_{x \in \mathbb{R}^n} \left[y^\top x - \frac12 \|x\|_2^2 \right]$, where $y$ is the given fixed vector
#
# - (2 pts) $\min_{x \in \mathbb{R}^n} \frac12 \|x - y \|_2^2 + \lambda \sum_{i=1}^{n-1} (x_i - x_{i+1})^2$, where $y$ is a given fixed vector of the proper dimension
#
# - (2 pts) $\min_{x \in \mathbb{R}^n} c^\top x \quad \text{s.t. } x \geq 0$, where $c$ is a given fixed vector of the proper dimension
#
# - (1 pts) $\min_{x \in \mathbb{R}^n} \frac12 \|x - y \|_2 \quad \text{s.t. } \|x\|_2 \leq 1 $, where $y$ is a given fixed vector of the proper dimension

# %%
# Your solution is here

# %% [markdown]
# ## Problem 2
#
# 1. (2 pts) Verify with cvxpy that your solutons of problems from 1.3 are correct
#
# 2. (1 pts) Write a paragraph about the most interesting topic from the course and the least interesting topic and motivate your choice
#
# 3. (2 pts) What are the key factors/ingredients that can help in successful exploitation of the stochastic gradient based optimizers?

# %%
# Your solution is here
